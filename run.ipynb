# %%
# !pip install scikit-learn==0.22.2

# %%
# Random Seed 설정
import random
import numpy as np

seed = 42
random.seed(seed)
np.random.seed(seed)

# %%
#detection해서 추적 파일을 배열 파일인 npy로 만들어줌
# Random Seed 설정
import random
import numpy as np

seed = 42
random.seed(seed)
np.random.seed(seed)

from timeit import time
start = time.time()
# !python tools/generate_detections.py \
    --model=resources/networks/mars-small128.pb \
    --mot_dir=./MOT16/train/aa \
    --output_dir=.result/resources/detections/MOT16_train

#deep_sort_app에서 디스플레이만 빼고 npy파일을 txt로 정리
# !python evaluate_motchallenge.py \
    --mot_dir=./MOT16/train/aa\
    --detection_dir=.result/resources/detections/MOT16_train\
    --output_dir=./output/output2 \
    --min_confidence=0.3 \
    --min_detection_height=0 \
    --nn_budget=100     
    
print("시간")
print("time :", time.time() - start)
# Out:
# Processing MOT16-02
# Frame 00001/00600
# Frame 00002/00600
# Frame 00003/00600
# Frame 00004/00600
# Frame 00005/00600
# Frame 00006/00600
# Frame 00007/00600
# Frame 00008/00600
# Frame 00009/00600
# Frame 00010/00600
# Frame 00011/00600
# Frame 00012/00600
# Frame 00013/00600
# Frame 00014/00600
# Frame 00015/00600
# Frame 00016/00600
# Frame 00017/00600
# Frame 00018/00600
# Frame 00019/00600
# Frame 00020/00600
# Frame 00021/00600
# Frame 00022/00600
# Frame 00023/00600
# Frame 00024/00600
# Frame 00025/00600
# Frame 00026/00600
# Frame 00027/00600
# Frame 00028/00600
# Frame 00029/00600
# Frame 00030/00600
# Frame 00031/00600
# Frame 00032/00600
# Frame 00033/00600
# Frame 00034/00600
# Frame 00035/00600
# Frame 00036/00600
# Frame 00037/00600
# Frame 00038/00600
# Frame 00039/00600
# Frame 00040/00600
# Frame 00041/00600
# Frame 00042/00600
# Frame 00043/00600
# Frame 00044/00600
# Frame 00045/00600
# Frame 00046/00600
# Frame 00047/00600
# Frame 00048/00600
# ...

# %%
#detection해서 추적 파일을 배열 파일인 npy로 만들어줌
# Random Seed 설정
import random
import numpy as np

seed = 42
random.seed(seed)
np.random.seed(seed)

from timeit import time
start = time.time()
# !python tools/generate_detections.py \
    --model=resources/networks/mars-small128.pb \
    --mot_dir=./MOT16/train/aa \
    --output_dir=.result/resources/detections/MOT16_train   
    
print("시간")
print("time :", time.time() - start)
# Out:
# Processing MOT16-02
# Frame 00001/00600
# Frame 00002/00600
# Frame 00003/00600
# Frame 00004/00600
# Frame 00005/00600
# Frame 00006/00600
# Frame 00007/00600
# Frame 00008/00600
# Frame 00009/00600
# Frame 00010/00600
# Frame 00011/00600
# Frame 00012/00600
# Frame 00013/00600
# Frame 00014/00600시간
# time : 132.43085551261902
# 2021-05-02 23:23:37.993439: I C:\tf_jenkins\workspace\rel-win\M\windows\PY\36\tensorflow\core\platform\cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# Frame 00015/00600
# Frame 00016/00600
# Frame 00017/00600
# Frame 00018/00600
# Frame 00019/00600
# Frame 00020/00600
# Frame 00021/00600
# Frame 00022/00600
# Frame 00023/00600
# Frame 00024/00600
# Frame 00025/00600
# Frame 00026/00600
# Frame 00027/00600
# Frame 00028/00600
# Frame 00029/00600
# Frame 00030/00600
# Frame 00031/00600
# Frame 00032/00600
# Frame 00033/00600
# Frame 00034/00600
# Frame 00035/00600
# Frame 00036/00600
# ...

# %%
#deep_sort_app에서 디스플레이만 빼고 npy파일을 txt로 정리
# !python evaluate_motchallenge.py \
    --mot_dir=./MOT16/train/aa\
    --detection_dir=resources/detections/MOT16_train \
    --output_dir=./output/output2 \
    --min_confidence=0.3 \
    --min_detection_height=0 \
    --nn_budget=100
# Out:
# Running sequence MOT16-02
# Processing frame 00001
# Processing frame 00002
# Processing frame 00003
# Processing frame 00005
# Processing frame 00006
# Processing frame 00007
# Processing frame 00009
# Processing frame 00010
# Processing frame 00011
# Processing frame 00013
# Processing frame 00014
# Processing frame 00015
# Processing frame 00017
# Processing frame 00018
# Processing frame 00019
# Processing frame 00021
# Processing frame 00022
# Processing frame 00023
# Processing frame 00025
# Processing frame 00026
# Processing frame 00027
# Processing frame 00029
# Processing frame 00030
# Processing frame 00031
# Processing frame 00033
# Processing frame 00034
# Processing frame 00035
# Processing frame 00037
# Processing frame 00038
# Processing frame 00039
# Processing frame 00041
# Processing frame 00042
# Processing frame 00043
# Processing frame 00045
# Processing frame 00046
# Processing frame 00047
# Processing frame 00049
# Processing frame 00050
# ...

# %% [markdown]
# ### ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ

# %%
#npy파일을 읽어서 디스플레이로 띄우기
# !python deep_sort_app.py \
    --sequence_dir=./MOT16/train/dd/MOT16-02\
    --detection_file=./resources/detections/MOT16_train/MOT16-02.npy \
    --output_file=./output/output.txt \
    --min_confidence=0.3 \
    --nn_budget=100 \
    --display=True
# Out:
# Processing frame 00001
# Processing frame 00002
# Processing frame 00003
# Processing frame 00004
# Processing frame 00005
# Processing frame 00006
# Processing frame 00007
# Processing frame 00008
# Processing frame 00009
# Processing frame 00010
# Processing frame 00011
# Processing frame 00012
# Processing frame 00013
# Processing frame 00014
# Processing frame 00015
# Processing frame 00016
# Processing frame 00017
# Processing frame 00018
# Processing frame 00019
# Processing frame 00020
# Processing frame 00021
# Processing frame 00022
# Processing frame 00023
# Processing frame 00024
# Processing frame 00025
# Processing frame 00026
# Processing frame 00027
# Processing frame 00028
# Processing frame 00029
# Processing frame 00030
# Processing frame 00031
# Processing frame 00032
# Processing frame 00033
# Processing frame 00034
# Processing frame 00035
# Processing frame 00036
# Processing frame 00037
# Processing frame 00038
# Processing frame 00039
# Processing frame 00040
# ...

# %%
# !python evaluate_motchallenge.py -h
# Out:
# usage: evaluate_motchallenge.py [-h] --mot_dir MOT_DIR --detection_dir
#                                 DETECTION_DIR [--output_dir OUTPUT_DIR]
#                                 [--min_confidence MIN_CONFIDENCE]
#                                 [--min_detection_height MIN_DETECTION_HEIGHT]
#                                 [--nms_max_overlap NMS_MAX_OVERLAP]
#                                 [--max_cosine_distance MAX_COSINE_DISTANCE]
#                                 [--nn_budget NN_BUDGET]
#
# MOTChallenge evaluation
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --mot_dir MOT_DIR     Path to MOTChallenge directory (train or test)
#   --detection_dir DETECTION_DIR
#                         Path to detections.
#   --output_dir OUTPUT_DIR
#                         Folder in which the results will be stored. Will be
#                         created if it does not exist.
#   --min_confidence MIN_CONFIDENCE
# ...

# %%
# !python evaluate_motchallenge.py \
    --mot_dir=./MOT16/train/gg \
    --detection_dir=./resources/detections/MOT16_train \
    --output_dir=./MOT16_02_output_frameskip2_1
# Out:
# Running sequence MOT16-13
# Processing frame 00001
# Processing frame 00002
# Processing frame 00003
# Processing frame 00004
# Processing frame 00005
# Processing frame 00007
# Processing frame 00008
# Processing frame 00009
# Processing frame 00010
# C:\Users\RTCL4\anaconda3\envs\mot\lib\site-packages\sklearn\utils\linear_assignment_.py:22: FutureWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# C:\Users\RTCL4\anaconda3\envs\mot\lib\site-packages\sklearn\utils\linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Processing frame 00011
# Processing frame 00013
# Processing frame 00014
# Processing frame 00016
# Processing frame 00017
# Processing frame 00019
# Processing frame 00020
# Processing frame 00022
# ...
